# %% [markdown]
# # 1. Instanciação do MeshAutoencoder
#
# O MeshAutoencoder representa a primeira etapa da arquitetura MeshGPT.
# Seu objetivo é aprender uma representação latente discreta das malhas tridimensionais, permitindo posteriormente que o Transformer modele essa sequência de códigos.
#
# Nesta etapa é criado apenas o modelo, sem treinamento.

# %%
import torch
import sys

print("=" * 60)
print("MeshGPT - Ambiente")
print("=" * 60)

print("Python :", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# ...
# MeshGPT - Ambiente
# ...
# Python : 3.10.20 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:13:20) [MSC v.1942 64 bit (AMD64)]
# PyTorch: 2.12.1+cpu
# CUDA: False

# %%
from meshgpt_pytorch import MeshAutoencoder, MeshTransformer

print("MeshGPT importado com sucesso!")
# Out:
# MeshGPT importado com sucesso!

# %%
import torch
from meshgpt_pytorch import MeshAutoencoder

autoencoder = MeshAutoencoder(
    num_discrete_coors=128
)

vertices = torch.randn((2, 121, 3))
faces = torch.randint(0, 121, (2, 64, 3))

print("vertices:", vertices.shape)
print("faces:", faces.shape)
print("Modelo criado com sucesso!")
# Out:
# vertices: torch.Size([2, 121, 3])
# faces: torch.Size([2, 64, 3])
# Modelo criado com sucesso!
